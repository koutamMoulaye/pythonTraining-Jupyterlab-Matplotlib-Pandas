# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male  \
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df["email"]
# Out:
# 0            malders0@shop-pro.jp
# 1              hharridge1@gnu.org
# 2           ekilminster2@etsy.com
# 3                gbrantl3@umn.edu
# 4             kbeasant4@jigsy.com
#                   ...
# 995          derrigorn@elpais.com
# 996         arastallro@toplist.cz
# 997    bstickelsrp@cloudflare.com
# 998        ptesoerq@rakuten.co.jp
# 999         rpringuerrr@house.gov
# Name: email, Length: 1000, dtype: object

# %%
df["email"].head()
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
df.email.head()
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %% [markdown]
# # the object DataFrame means the all of our data table columns and line

# %% [markdown]
# # the difference between the object DataFrame and serie

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # the Serie object is in particular a single comlun defined with the data so it is a part of the DataFrame

# %%
type(df.email)
# Out:
# pandas.core.series.Series

# %%
df[10:20]
# Out:
#     id        date first_name  last_name                       email  gender
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male  \
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
# 14  15  03/21/2021     Oralie     Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina      Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve    Allaway        eallawayg@ebay.co.uk  Female
# 17  18  03/20/2021       Esta    Boulden     ebouldenh@posterous.com     NaN
# 18  19  03/16/2021      Judye      Behan           jbehani@google.es  Female
# 19  20  03/01/2021     Sibeal     Mounch      smounchj@rakuten.co.jp    Male
#
#          ip_address        country price_paid   tax
# 10    201.76.240.51         Canada      $5.71   NaN
# ...

# %%
df.loc[10:13]
# Out:
#     id        date first_name  last_name                       email  gender
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male  \
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
#
#         ip_address        country price_paid   tax
# 10   201.76.240.51         Canada      $5.71   NaN
# 11  222.60.138.222  United States      $3.15  20.0
# 12   24.25.198.252         Canada      $5.30  20.0
# 13    18.203.61.94         France      $5.97  20.0

# %%
df.set_index("id")
# Out:
#             date first_name   last_name                       email  gender
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male  \
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
# ...

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male  \
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df.set_index("id", inplace=True)

# %%
df.head()
# Out:
#           date first_name   last_name                  email  gender
# id
# 1   03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male  \
# 2   03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 3   03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 4   03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 5   03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#          ip_address        country price_paid   tax
# id
# 1     160.119.8.119         Canada      $5.36   NaN
# 2    210.51.172.132         Canada      $8.32   NaN
# 3     213.8.101.145  United States      $3.73  20.0
# 4     5.140.237.101  United States      $3.70  20.0
# 5   106.252.162.233        Morocco      $9.24  20.0

# %%
df.columns
# Out:
# Index(['date', 'first_name', 'last_name', 'email', 'gender', 'ip_address',
#        'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df_email = df.set_index("email")

# %%
df_email.head(12)
# Out:
#                                  date first_name   last_name  gender
# email
# malders0@shop-pro.jp       03/28/2021    Marylin      Alders    Male  \
# hharridge1@gnu.org         03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com      03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu           03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com        03/24/2021      Kanya     Beasant    Male
# tbraybrooke5@umn.edu       03/25/2021      Titos  Braybrooke  Female
# akencott6@phoca.cz         03/14/2021        Ava     Kencott  Female
# cfeasley7@ed.gov           03/08/2021       Codi     Feasley    Male
# wheersema8@tumblr.com      03/09/2021     Waylon    Heersema    Male
# ggookes9@amazon.co.uk      03/23/2021  Guglielma      Gookes    Male
# lwoodcrafta@sitemeter.com  03/11/2021       Lief   Woodcraft    Male
# bwymanb@lulu.com           03/16/2021     Bailie       Wyman    Male
#
# ...

# %%
df_email.loc['malders0@shop-pro.jp'].values.tolist()
# Out:
# ['03/28/2021',
#  'Marylin',
#  'Alders',
#  'Male',
#  '160.119.8.119',
#  'Canada',
#  '$5.36',
#  nan]

# %%
type(df_email.loc[['ekilminster2@etsy.com','ggookes9@amazon.co.uk']])
# Out:
# pandas.core.frame.DataFrame
