# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df["gender"] == "Male"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df["gender"] == "Female"]
# Out:
#       id        date first_name   last_name                       email
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org  \
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df["country"].isin(["France","Canada"])
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: country, Length: 1000, dtype: bool

# %%
country_filter=df[df["country"].isin(["France","Canada"])]
country_filter
# Out:
#        id        date first_name   last_name                      email
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp  \
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
df[df["price_paid"] == "$8.32"]
# Out:
#       id        date first_name last_name                  email  gender
# 1      2  03/19/2021      Hinda  Harridge     hharridge1@gnu.org  Female  \
# 485  486  03/24/2021      Erich  Sinfield  esinfielddh@wiley.com    Male
#
#          ip_address country price_paid   tax
# 1    210.51.172.132  Canada      $8.32   NaN
# 485  166.95.153.128  France      $8.32  20.0

# %%
df_test = df.copy()
df_test.price_paid = df_test.price_paid.apply(lambda x : x.replace("$", ""))
df_test.price_paid = df_test.price_paid.astype(float)
df_test[df_test["price_paid"] >= 5]
# Out:
#        id        date first_name   last_name                       email
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp  \
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %% [markdown]
# # here i replace the value from my gender column

# %%
df_test3 = df.copy()
df_test3.gender = df_test3.gender.replace(["Female"], "$femelle")
df_test3.gender = df_test3.gender.astype(str)
df_test3[df_test3["gender"] == "$femelle"]
# Out:
#       id        date first_name   last_name                       email
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org  \
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#        gender      ip_address        country price_paid   tax
# ...

# %% [markdown]
# # now i want to replace a particular part in my values from gender column i mean "$" --> " "

# %%
df_test3= df_test.copy()
df_test3.gender = df_test3.gender.apply(lambda x : x.replace("$", ""))
df_test3.gender = df_test3.gender.astype(str)
df_test3[df_test3["gender"] == "femelle"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 df_test3= df_test.copy()
# ----> 2 df_test3.gender = df_test3.gender.apply(lambda x : x.replace("$", ""))
#       3 df_test3.gender = df_test3.gender.astype(str)
#       4 df_test3[df_test3["gender"] == "femelle"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4631, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4521 def apply(
#    4522     self,
#    4523     func: AggFuncType,
#    (...)
#    4526     **kwargs,
#    4527 ) -> DataFrame | Series:
#    4528     """
#    4529     Invoke function on values of Series.
#    4530
#    (...)
#    4629     dtype: float64
#    4630     """
# -> 4631     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
df_test3.gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998      Male
# 999       NaN
# Name: gender, Length: 1000, dtype: object
